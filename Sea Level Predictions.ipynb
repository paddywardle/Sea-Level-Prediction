# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np

# %%
df = pd.read_csv('epa-sea-level.csv')

# %% [markdown]
# 1) Use matplotlib to create a scatter plot using the "Year" column as the x-axis and the "CSIRO Adjusted Sea Level" column as the y-axix.

# %%
plt.figure(figsize=(15,10))

plt.scatter(df.Year, df["CSIRO Adjusted Sea Level"])

plt.xlabel('Year')

plt.ylabel("CSIRO Adjusted Sea Level")

plt.title("The change in sea level by year")
# Out:
# Text(0.5, 1.0, 'The change in sea level by year')

# %% [markdown]
# 2) Use the linregress function from scipy.stats to get the slope and y-intercept of the line of best fit. Plot the line of best fit over the top of the scatter plot. Make the line go through the year 2050 to predict the sea level rise in 2050.

# %%
regression = linregress(df.Year, df["CSIRO Adjusted Sea Level"])

# %%
print(regression.slope, regression.intercept)
# Out:
# 0.0630445840121348 -119.06594196773978

# %%
x = df.Year
y = df["CSIRO Adjusted Sea Level"]
y_pred = regression.slope * x + regression.intercept

# %%
plt.figure(figsize=(15, 10))
plt.scatter(x, y, label='Original Data')
plt.plot(x, y_pred, label='Regression Model', color='red')
plt.legend()
plt.xlabel('Year')
plt.ylabel("CSIRO Adjusted Sea Level")
plt.title("The change in sea level by year")
# Out:
# Text(0.5, 1.0, 'The change in sea level by year')

# %% [markdown]
# 3) Plot a new line of best fit just using the data from year 2000 through the most recent year in the dataset. Make the line also go through the year 2050 to predict the sea level rise in 2050 if the rate of rise continues as it has since the year 2000.

# %%
df_from_2000 = df[df.Year >= 2000]

# %%
x_from_2000 = df_from_2000.Year
y_from_2000 = df_from_2000["CSIRO Adjusted Sea Level"]

# %%
regression_from_2000 = linregress(x_from_2000, y_from_2000)

# %%
x_to_2050 = list(x_from_2000) + list(range(2014, 2051,1))

# %%
x_2050_series = pd.Series(x_to_2050)

# %%
y_2050_preds = regression_from_2000.slope * x_2050_series + regression_from_2000.intercept

# %%
plt.figure(figsize=(15,10))
plt.scatter(x_from_2000, y_from_2000, label='Original Data')
plt.plot(x_to_2050, y_2050_preds, label='Regression Model', color='red')
plt.legend()
plt.xlabel('Year')
plt.ylabel("Sea Level (inches)")
plt.title("Rise in Sea Level")
# Out:
# Text(0.5, 1.0, 'Rise in Sea Level')

# %% [markdown]
# 4) The x label should be "Year", the y label should be "Sea Level (inches)", and the title should be "Rise in Sea Level".
